# %% [markdown]
# <a href="https://colab.research.google.com/github/idkidk699/learnpython/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image

# %%
img = Image.open('evil peppa.jpeg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x180>

# %%
img.size
# Out:
# (320, 180)

# %%
img.convert("L")
# Out:
# <PIL.Image.Image image mode=L size=320x180>

# %%
img01 = img.copy()

# %%
img01.thumbnail((200, 200))

# %%
img01.transpose?
# Out:
# Object `image01.transpose` not found.

# %%
img01.transpose(Image.Transpose.ROTATE_90)
# Out:
# <PIL.Image.Image image mode=RGB size=113x200>

# %%
img02 = img.convert("L")

# %%
img01.rotate?

# %%
r, g, b = img.split()
Image.merge('RGB', (b, g, r))
# Out:
# <PIL.Image.Image image mode=RGB size=320x180>
